# %%
# !nvidia-smi
# Out:
# Tue Feb 17 11:29:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 35%   31C    P8             15W /  170W |     530MiB /  12288MiB |      5%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            5112    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            7512    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A            9172    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15600    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           16200    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           16496    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           16696    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           17984    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           18584    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           19172    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           20496    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           20548    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           20984    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           24532    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.2-cp39-cp39-win_amd64.whl.metadata (115 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in .\appdata\local\anaconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in .\appdata\local\anaconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp39-cp39-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\appdata\local\anaconda3\envs\tf_gpu\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.1.0 in .\appdata\local\anaconda3\envs\tf_gpu\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in .\appdata\local\anaconda3\envs\tf_gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ------------------------------------- -- 7.3/7.8 MB 37.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 23.1 MB/s  0:00:00
# Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.2-cp39-cp39-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 8.2 MB/s  0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Downloading pillow-11.3.0-cp39-cp39-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------------- -------------------- 3.4/7.0 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 17.2 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    --------------- ------------------------ 3/8 [importlib-resources]
#    --------------- ------------------------ 3/8 [importlib-resources]
#    --------------- ------------------------ 3/8 [importlib-resources]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    ------------------------- -------------- 5/8 [cycler]
#    ------------------------------ --------- 6/8 [contourpy]
#    ------------------------------ --------- 6/8 [contourpy]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ---------------------------------------- 8/8 [matplotlib]
#
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.2 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.3.0 pyparsing-3.3.2

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train,y_train),(X_test,y_test)= mnist.load_data()
X_test_images=X_test

X_train=X_train.reshape(-1,784)
X_test=X_test.reshape(-1,784)

y_train_cat=to_categorical(y_train,10)
y_test_cat=to_categorical(y_test,10)

with tf.device('/GPU:0'):

    model=Sequential([
        Dense(128,activation='relu',input_shape=(784,)),
        Dense(64,activation='relu'),
        Dense(10,activation='softmax')
    ])

    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

    history=model.fit(
    X_train,y_train_cat,
    epochs=50,
    batch_size=32,
    validation_split=0.1
    )





    loss,accuracy=model.evaluate(X_test,y_test_cat,verbose=0)
# Out:
# Epoch 1/50
# 1688/1688 [==============================] - 7s 4ms/step - loss: 1.4528 - accuracy: 0.8267 - val_loss: 0.3292 - val_accuracy: 0.9138
# Epoch 2/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3129 - accuracy: 0.9160 - val_loss: 0.2108 - val_accuracy: 0.9420
# Epoch 3/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2170 - accuracy: 0.9403 - val_loss: 0.1801 - val_accuracy: 0.9470
# Epoch 4/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1742 - accuracy: 0.9513 - val_loss: 0.1579 - val_accuracy: 0.9575
# Epoch 5/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1461 - accuracy: 0.9594 - val_loss: 0.1512 - val_accuracy: 0.9590
# Epoch 6/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1322 - accuracy: 0.9641 - val_loss: 0.1235 - val_accuracy: 0.9667
# Epoch 7/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1150 - accuracy: 0.9686 - val_loss: 0.1444 - val_accuracy: 0.9618
# Epoch 8/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1041 - accuracy: 0.9728 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 9/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0966 - accuracy: 0.9743 - val_loss: 0.1285 - val_accuracy: 0.9682
# Epoch 10/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0836 - accuracy: 0.9775 - val_loss: 0.1276 - val_accuracy: 0.9697
# Epoch 11/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0892 - accuracy: 0.9771 - val_loss: 0.1581 - val_accuracy: 0.9678
# Epoch 12/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0759 - accuracy: 0.9811 - val_loss: 0.1335 - val_accuracy: 0.9707
# Epoch 13/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0743 - accuracy: 0.9815 - val_loss: 0.1344 - val_accuracy: 0.9700
# Epoch 14/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0627 - accuracy: 0.9838 - val_loss: 0.1558 - val_accuracy: 0.9705
# Epoch 15/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0656 - accuracy: 0.9832 - val_loss: 0.1529 - val_accuracy: 0.9677
# Epoch 16/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0612 - accuracy: 0.9843 - val_loss: 0.1714 - val_accuracy: 0.9700
# Epoch 17/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0617 - accuracy: 0.9850 - val_loss: 0.1377 - val_accuracy: 0.9775
# Epoch 18/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0607 - accuracy: 0.9853 - val_loss: 0.1545 - val_accuracy: 0.9718
# Epoch 19/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0561 - accuracy: 0.9863 - val_loss: 0.1716 - val_accuracy: 0.9745
# Epoch 20/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0639 - accuracy: 0.9849 - val_loss: 0.1505 - val_accuracy: 0.9748
# Epoch 21/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0595 - accuracy: 0.9864 - val_loss: 0.1601 - val_accuracy: 0.9725
# Epoch 22/50
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.0516 - accuracy: 0.9880 - val_loss: 0.1499 - val_accuracy: 0.9745
# Epoch 23/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0595 - accuracy: 0.9866 - val_loss: 0.1843 - val_accuracy: 0.9725
# Epoch 24/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0489 - accuracy: 0.9885 - val_loss: 0.1844 - val_accuracy: 0.9713
# Epoch 25/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0576 - accuracy: 0.9874 - val_loss: 0.1743 - val_accuracy: 0.9720
# Epoch 26/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0473 - accuracy: 0.9896 - val_loss: 0.1911 - val_accuracy: 0.9698
# Epoch 27/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0481 - accuracy: 0.9887 - val_loss: 0.2263 - val_accuracy: 0.9653
# Epoch 28/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0498 - accuracy: 0.9885 - val_loss: 0.2250 - val_accuracy: 0.9718
# Epoch 29/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0558 - accuracy: 0.9884 - val_loss: 0.1761 - val_accuracy: 0.9692
# Epoch 30/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0473 - accuracy: 0.9887 - val_loss: 0.2593 - val_accuracy: 0.9708
# Epoch 31/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0485 - accuracy: 0.9890 - val_loss: 0.2034 - val_accuracy: 0.9708
# Epoch 32/50
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.0444 - accuracy: 0.9898 - val_loss: 0.2005 - val_accuracy: 0.9675
# Epoch 33/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0437 - accuracy: 0.9899 - val_loss: 0.2264 - val_accuracy: 0.9733
# Epoch 34/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0487 - accuracy: 0.9897 - val_loss: 0.2810 - val_accuracy: 0.9735
# Epoch 35/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0598 - accuracy: 0.9885 - val_loss: 0.2209 - val_accuracy: 0.9738
# Epoch 36/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0354 - accuracy: 0.9916 - val_loss: 0.3114 - val_accuracy: 0.9712
# Epoch 37/50
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.0496 - accuracy: 0.9893 - val_loss: 0.2565 - val_accuracy: 0.9752
# Epoch 38/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0523 - accuracy: 0.9889 - val_loss: 0.2239 - val_accuracy: 0.9677
# Epoch 39/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0445 - accuracy: 0.9900 - val_loss: 0.2783 - val_accuracy: 0.9718
# Epoch 40/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0495 - accuracy: 0.9902 - val_loss: 0.2925 - val_accuracy: 0.9725
# Epoch 41/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0461 - accuracy: 0.9906 - val_loss: 0.2269 - val_accuracy: 0.9738
# Epoch 42/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0463 - accuracy: 0.9898 - val_loss: 0.2331 - val_accuracy: 0.9745
# Epoch 43/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0431 - accuracy: 0.9904 - val_loss: 0.2924 - val_accuracy: 0.9693
# Epoch 44/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0463 - accuracy: 0.9906 - val_loss: 0.2938 - val_accuracy: 0.9762
# Epoch 45/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0501 - accuracy: 0.9894 - val_loss: 0.3155 - val_accuracy: 0.9742
# Epoch 46/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0412 - accuracy: 0.9914 - val_loss: 0.3507 - val_accuracy: 0.9718
# Epoch 47/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0534 - accuracy: 0.9896 - val_loss: 0.2806 - val_accuracy: 0.9732
# Epoch 48/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0505 - accuracy: 0.9903 - val_loss: 0.2220 - val_accuracy: 0.9717
# Epoch 49/50
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0432 - accuracy: 0.9911 - val_loss: 0.3961 - val_accuracy: 0.9677
# Epoch 50/50
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0493 - accuracy: 0.9895 - val_loss: 0.3514 - val_accuracy: 0.9715

# %%
print(accuracy)
print(loss)
# Out:
# 0.9706000089645386
# 0.38873445987701416
